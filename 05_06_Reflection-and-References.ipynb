# %% [markdown]
# <div class="warning" style='background-color:#AEC6CF; color: #000435; border-left: solid #003e87 10px; border-radius: 4px; padding:0.7em;'>
# <span>
# <p style='margin-top:1em; text-align:center'>
# <b>ĐỒ ÁN CUỐI KỲ</b>
# <p style='margin-top:1em; text-align:center'>
# <b>CSC17104 - Lập trình cho Khoa học Dữ liệu, 21KHDL1</b></p>
# <p style='margin-left:1em;'>
#
# **Thành viên thực hiện:**
# - 21127612 - Nguyễn Khánh Hoàng ('nkhoang21@clc.fitus.edu.vn')
# - 21127423 - Trần Hiếu Tâm ('thtam21@clc.fitus.edu.vn')
#
# **Tên đề tài:** Phân tích tổng quan thị trường lao động ngành CNTT trên toàn cầu, giai đoạn 2021-2023 <br><br>
# </p>
# </p></span>
# </div>

# %% [markdown]
# **<h1><center>Phần 5-6: Đánh giá quá trình làm việc - Danh mục Tài liệu tham khảo</center></h1>**
# <a id="top"></a>
# <div class="list-group" id="list-tab" role="tablist">
#     <h3 style="text-align: left; font-family:arial; padding: 14px; line-height: 1; border-radius:10px"><b>Mục lục</b></h3>
#
#    * [1. Đánh giá quá trình làm việc](#1)
#    * [2. Danh mục tài liệu tham khảo](#2)

# %% [markdown]
# ### **Căn cứ đánh giá**
# - Kế hoạch thực hiện: Trên [Google sheet](https://docs.google.com/spreadsheets/d/1GHKwFt-alekIcUxujsa5rN-wUFnf7W3D/edit#gid=72322104) hoặc [Trello]()
# - Tổ chức mã nguồn: [GitHub](https://github.com/BoonRealCuaaaaa/P4DS-final)

# %% [markdown]
# <a id="1"></a>
# #### <div style="text-align: left; background-color:#003e87; font-family:arial;color: white; padding: 14px; line-height: 1;font-weight: bold; border-radius:10px">1. Đánh giá quá trình làm việc</div>

# %% [markdown]
# #### **<font color = #E7B10A> 🔍Khó khăn trong quá trình thực hiện (cá nhân):** </font>

# %% [markdown]
# <div class="warning" style='background-color:#C1E1C1; color: #001C00; border-left: solid #001C00 10px; border-radius: 4px; padding:0.7em;'>
# <span>
#
# <b>Sinh viên báo cáo:</b> Nguyễn Khánh Hoàng
#
# <b>Mã số sinh viên:</b> 21127612
#
# <b>Email liên hệ:</b> nkhoang21@clc.fitus.edu.vn
#
# Nội dung báo cáo về <b>Khó khăn trong quá trình thực hiện</b> như sau:
# - Việc tìm kiếm bộ dữ liệu phù hợp với danh sách tiêu chí đã đề ra gặp nhiều khó khăn, khó để chu toàn toàn bộ tất cả các tiêu chí được. Trong quá trình tìm hiểu thì không dễ dàng để tìm được dữ liệu như ý, kích thước đủ lớn và ít dữ liệu rác.
# - Do hạn chế về năng lực của bản thân, cũng như độ phức tạp của các câu hỏi đưa ra dẫn đến việc phân tích và vạch ra định hướng để tìm ra câu trả lời mang tính thuyết phục, chặt chẽ cao gặp nhiều khó khăn. Đây là một trong những khâu tốn thời gian nhiều nhất trong tổng thời gian thực hiện đồ án.
# - Khó khăn trong việc quản lý git đối với file .md
#
# </p>
# </p></span>
# </div>

# %% [markdown]
# <div class="warning" style='background-color:#C1E1C1; color: #001C00; border-left: solid #001C00 10px; border-radius: 4px; padding:0.7em;'>
# <span>
#
# <b>Sinh viên báo cáo:</b> Trần Hiếu Tâm
#
# <b>Mã số sinh viên:</b> 21127423
#
# <b>Email liên hệ:</b> thtam21@clc.fitus.edu.vn
#
# Nội dung báo cáo về <b>Khó khăn trong quá trình thực hiện</b> như sau:
# - Dữ liệu gây nhiễu còn nhiều, gây hậu quả nghiêm trọng nhưng xuất hiện ở tần suất không cao, không có dấu hiệu rõ ràng nên việc phát hiện và có các bước xử lý còn nhiều khó khăn. Đồng thời việc thực hiện các thao tác tổ chức mã nguồn còn thiếu chuyên nghiệp.
# - Việc quản lý thời gian cá nhân có khuyết điểm, chưa quản lý và sắp xếp phù hợp với thời gian chung của nhóm.
#
# </p>
# </p></span>
# </div>

# %% [markdown]
# #### **<font color = #E7B10A> 🔍Kiến thức đạt được (cá nhân):** </font>

# %% [markdown]
# <div class="warning" style='background-color:#C1E1C1; color: #001C00; border-left: solid #001C00 10px; border-radius: 4px; padding:0.7em;'>
# <span>
#
# <b>Sinh viên báo cáo:</b> Nguyễn Khánh Hoàng
#
# <b>Mã số sinh viên:</b> 21127612
#
# <b>Email liên hệ:</b> nkhoang21@clc.fitus.edu.vn
#
# Nội dung báo cáo về <b>Kiến thức đạt được</b> như sau:
# - Đạt được một số thành tựu trong việc phát triển tư duy định hướng cách giải quyết, trả lời các vấn đề một cách khoa học, logic, thuyết phục và chặt chẽ hơn. Định hướng thực hiện việc xử lý và phân tích dữ liệu theo hướng chuyên nghiệp hơn.
# - Kiến thức về xây dựng và vận dụng hiệu quả các loại biểu đồ trong việc trực quan hóa dữ liệu, tối ưu hóa kết quả để đạt được mục tiêu kỳ vọng đề ra.
#
# </p>
# </p></span>
# </div>

# %% [markdown]
# <div class="warning" style='background-color:#C1E1C1; color: #001C00; border-left: solid #001C00 10px; border-radius: 4px; padding:0.7em;'>
# <span>
#
# <b>Sinh viên báo cáo:</b> Trần Hiếu Tâm
#
# <b>Mã số sinh viên:</b> 21127423
#
# <b>Email liên hệ:</b> thtam21@clc.fitus.edu.vn
#
# Nội dung báo cáo về <b>Kiến thức đạt được</b> như sau:
# - Quy trình thực hiện một dự án, đồ án, đề tài lĩnh vực khoa học dữ liệu theo hướng chuyên nghiệp và chặt chẽ. Từ đó có định hướng tốt hơn trong quá trình tiếp cận và khai thác dữ liệu hiệu quả hơn, mang lại kết quả cao nhất và khách quan nhất.
# - Hiểu cách vận dụng một số công cụ hỗ trợ hữu ích và hiệu quả, mang lại hiệu suất cao cho ngành Khoa học dữ liệu nói riêng và Công nghệ thông tin nói chung.
#
# </p>
# </p></span>
# </div>

# %% [markdown]
# #### **<font color = #E7B10A> 🔍Định hướng phát triển đề tài (nhóm):** </font>

# %% [markdown]
# <div class="warning" style='background-color:#FDFD96; color: #331800; border-left: solid #E7B10A 20px; border-radius: 10px; padding:0.7em;'>
# <span>
#
# <b>Sinh viên báo cáo:</b> Nguyễn Khánh Hoàng, Trần Hiếu Tâm
#
# <b>Tên đề tài:</b> Phân tích mức lương của Lập trình viên trên toàn cầu, giai đoạn 2021-2023
#
# <b>Nguồn dữ liệu:</b> [Stack Overflow Annual Developer Survey](https://insights.stackoverflow.com/survey)
#
# <b>Email liên hệ:</b> nkhoang21@clc.fitus.edu.vn, thtam21@clc.fitus.edu.vn
#
# Nội dung báo cáo về <b>Định hướng phát triển đề tài</b> như sau:
# - Thu thập thêm các bộ dữ liệu có liên quan để 'làm giàu' cho dữ liệu, giảm tỉ lệ dữ liệu rác hoặc dữ liệu gây nhiễu. Từ đó đưa ra được kết luận chính xác, khách quan hơn.
# - Tìm hiểu xây dựng các mô hình học máy để dự đoán, đưa ra khuyến cáo để có thể tận dụng được tối đa lợi ích mà dữ liệu mang lại cho cộng đồng.
#
# </p>
# </p></span>
# </div>

# %% [markdown]
# <a id="2"></a>
# #### <div style="text-align: left; background-color:#003e87; font-family:arial;color: white; padding: 14px; line-height: 1;font-weight: bold; border-radius:10px">2. Danh mục tài liệu tham khảo</div>

# %% [markdown]
# [1] Khoa Công nghệ Thông tin (Trường Đại học Khoa học Tự nhiên, ĐHQG-HCM), *Slide bài giảng Lý thuyết học phần Lập trình cho Khoa học dữ liệu*, Năm cập nhật: 2023, Tài liệu online, xem thêm tại [đây](https://drive.google.com/drive/folders/1FyzNTCs_xpx-CUVBw_VwXlEt73tf8ywX)
#
# [2] Khoa Công nghệ Thông tin (Trường Đại học Khoa học Tự nhiên, ĐHQG-HCM), *Tài liệu hướng dẫn thực hành học phần Lập trình cho Khoa học dữ liệu*, Năm cập nhật: 2023, Tài liệu online, xem thêm tại [đây](https://courses.ctda.hcmus.edu.vn/course/view.php?id=2914)
